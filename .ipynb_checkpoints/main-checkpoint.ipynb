# %%
import pandas as pd

# %%
tickers = [
            'JPM',
            'BAC',
            'C',
            'WFC',
            'GS',
            ]

# %%
bank_data = pd.read_json("./viz.json")

# %%
pd.DataFrame(bank_data)
# Out:
#                                                      JPM  \
# chart  [{'date': '2018-06-06', 'uClose': 110.36, 'uOp...
#
#                                                      BAC  \
# chart  [{'date': '2018-06-06', 'uClose': 30.04, 'uOpe...
#
#                                                        C  \
# chart  [{'date': '2018-06-06', 'uClose': 68.23, 'uOpe...
#
#                                                      WFC  \
# chart  [{'date': '2018-06-06', 'uClose': 55.58, 'uOpe...
#
#                                                       GS
# chart  [{'date': '2018-06-06', 'uClose': 232.23, 'uOp...

# %%
pd.DataFrame(bank_data['JPM']['chart'])
# Out:
#            date  uClose   uOpen   uHigh    uLow   uVolume   close    open  \
# 0    2018-06-06  110.36  108.66  110.74  108.48  15453563  110.36  108.66
# 1    2018-06-07  110.80  111.18  111.50  110.03  13444427  110.80  111.18
# 2    2018-06-08  111.11  110.62  111.14  110.06  10383168  111.11  110.62
# 3    2018-06-11  110.83  111.12  111.91  110.77  12642897  110.83  111.12
# 4    2018-06-12  110.19  111.14  111.53  109.52  15294082  110.19  111.14
# ..          ...     ...     ...     ...     ...       ...     ...     ...
# 499  2020-06-01   98.60   97.75   99.51   97.38  15207495   98.60   97.75
# 500  2020-06-02   98.93  100.28  100.42   97.93  21194963   98.93  100.28
# 501  2020-06-03  104.27  101.58  104.92  101.06  25941090  104.27  101.58
# 502  2020-06-04  106.44  103.82  106.61  102.79  26784723  106.44  103.82
# 503  2020-06-05  111.23  114.93  115.77  109.53  42230986  111.23  114.93
#
#        high     low    volume currency  change  changePercent       label  \
# 0    110.74  108.48  15453563             0.00         0.0000   Jun 6, 18
# 1    111.50  110.03  13444427             0.44         0.3987   Jun 7, 18
# 2    111.14  110.06  10383168             0.31         0.2798   Jun 8, 18
# 3    111.91  110.77  12642897            -0.28        -0.2520  Jun 11, 18
# 4    111.53  109.52  15294082            -0.64        -0.5775  Jun 12, 18
# ..      ...     ...       ...      ...     ...            ...         ...
# 499   99.51   97.38  15207495             1.29         1.3257   Jun 1, 20
# 500  100.42   97.93  21194963             0.33         0.3347   Jun 2, 20
# 501  104.92  101.06  25941090             5.34         5.3978   Jun 3, 20
# 502  106.61  102.79  26784723             2.17         2.0811   Jun 4, 20
# 503  115.77  109.53  42230986             4.79         4.5002   Jun 5, 20
#
#      changeOverTime
# 0          0.000000
# 1          0.003987
# 2          0.006796
# 3          0.004259
# 4         -0.001540
# ..              ...
# 499       -0.106560
# 500       -0.103570
# 501       -0.055183
# 502       -0.035520
# 503        0.007883
#
# [504 rows x 16 columns]

# %%
series_list = []

#Parsing a panda Series of closing prices for all the tickers
for ticker in tickers:
    series_list.append(pd.DataFrame(bank_data[ticker]['chart'])['close'])

#Appending the date column
series_list.append(pd.DataFrame(bank_data['JPM']['chart'])['date'])

#Setting the values of the columns
column_names = tickers.copy()
column_names.append('Date')

#Merging into one single dataframe
bank_data = pd.concat(series_list, axis=1)

#Setting column names and date as index 
bank_data.columns = column_names

bank_data.set_index('Date', inplace = True)

# %%
bank_data
# Out:
#                JPM    BAC      C    WFC      GS
# Date
# 2018-06-06  110.36  30.04  68.23  55.58  232.23
# 2018-06-07  110.80  30.09  68.45  55.63  233.45
# 2018-06-08  111.11  30.01  68.47  55.68  233.39
# 2018-06-11  110.83  30.06  68.11  55.51  234.09
# 2018-06-12  110.19  29.90  67.61  55.38  232.63
# ...            ...    ...    ...    ...     ...
# 2020-06-01   98.60  24.61  49.45  27.09  199.93
# 2020-06-02   98.93  24.84  50.84  27.40  204.14
# 2020-06-03  104.27  25.99  53.34  28.83  210.57
# 2020-06-04  106.44  26.78  55.65  30.22  214.82
# 2020-06-05  111.23  28.11  58.86  31.67  217.92
#
# [504 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.title('Box Plot of Bank Stock Prices',fontSize = 20)
# Out:
# Text(0.5, 1.0, 'Box Plot of Bank Stock Prices')

# %%
#Creating boxplots along columns
plt.boxplot(bank_data.transpose())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5e3495fc8>,
#   <matplotlib.lines.Line2D at 0x1f5e34986c8>,
#   <matplotlib.lines.Line2D at 0x1f5e34a5c48>,
#   <matplotlib.lines.Line2D at 0x1f5e34a0b88>,
#   <matplotlib.lines.Line2D at 0x1f5e34b6dc8>,
#   <matplotlib.lines.Line2D at 0x1f5e34b9a88>,
#   <matplotlib.lines.Line2D at 0x1f5e34ce5c8>,
#   <matplotlib.lines.Line2D at 0x1f5e34ced08>,
#   <matplotlib.lines.Line2D at 0x1f5e34ded08>,
#   <matplotlib.lines.Line2D at 0x1f5e34b94c8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f5e3498dc8>,
#   <matplotlib.lines.Line2D at 0x1f5e3498f08>,
#   <matplotlib.lines.Line2D at 0x1f5e34abf88>,
#   <matplotlib.lines.Line2D at 0x1f5e34af6c8>,
#   <matplotlib.lines.Line2D at 0x1f5e34b9bc8>,
#   <matplotlib.lines.Line2D at 0x1f5e34c2908>,
#   <matplotlib.lines.Line2D at 0x1f5e34cee88>,
#   <matplotlib.lines.Line2D at 0x1f5e34d2cc8>,
#   <matplotlib.lines.Line2D at 0x1f5e34e4c48>,
#   <matplotlib.lines.Line2D at 0x1f5e34c2308>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5e3495748>,
#   <matplotlib.lines.Line2D at 0x1f5e12a8288>,
#   <matplotlib.lines.Line2D at 0x1f5e34a5488>,
#   <matplotlib.lines.Line2D at 0x1f5e34b6608>,
#   <matplotlib.lines.Line2D at 0x1f5e34de548>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5e34a0c48>,
#   <matplotlib.lines.Line2D at 0x1f5e34afdc8>,
#   <matplotlib.lines.Line2D at 0x1f5e34c2a48>,
#   <matplotlib.lines.Line2D at 0x1f5e34d2e48>,
#   <matplotlib.lines.Line2D at 0x1f5e34eabc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5e34a0d88>,
#   <matplotlib.lines.Line2D at 0x1f5e34aff08>,
#   <matplotlib.lines.Line2D at 0x1f5e34c7748>,
#   <matplotlib.lines.Line2D at 0x1f5e34d8c88>,
#   <matplotlib.lines.Line2D at 0x1f5e34ef408>],
#  'means': []}
